# %%
d = {"key":"value","key1":"value1"}

# %%
d["key"]
# Out:
# 'value'

# %%
from box import ConfigBox

# %%
d2 = {"key":"value","key1":"value1"}

# %%
d2 =ConfigBox(d2)

# %%
d2
# Out:
# ConfigBox({'key': 'value', 'key1': 'value1'})

# %%
d2.key1
# Out:
# 'value1'

# %%
def get_product(x:int, y:int):
    return x*y

# %%
get_product(x = 2, y = 3)
# Out:
# 6

# %%
get_product(x = 2, y = "3")
# Out:
# '33'

# %%
from ensure import ensure_annotations

# %%
@ensure_annotations
def get_product(x:int, y:int):
    return x*y

# %%
get_product(x = 2, y = 3)
# Out:
# 6

# %% [markdown]
# Download data from gdrive

# %%
import gdown

# %%
url = "https://drive.google.com/file/d/1dSJlKUpZ7Zb1tPOtocj6mRASdzWaeBIw/view?usp=sharing"

# %%
type(url)
# Out:
# str

# %%
file_id = url.split("/")[-2]
file_id
# Out:
# '1dSJlKUpZ7Zb1tPOtocj6mRASdzWaeBIw'

# %%
prefix = 'https://drive.google.com/uc?/export=download&id='
gdown.download(prefix+file_id, "Chest-CT-Scan-data.zip")
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?/export=download&id=1dSJlKUpZ7Zb1tPOtocj6mRASdzWaeBIw
# From (redirected): https://drive.google.com/uc?%2Fexport=download&id=1dSJlKUpZ7Zb1tPOtocj6mRASdzWaeBIw&confirm=t&uuid=0949bd9f-97b4-49e0-ae14-2141f6bb64f0
# To: /home/karthik/Documents/Chest-Cancer-Diagnosis-Pipeline-with-MLflow-and-DVC/Chest-Cancer-Diagnosis-Pipeline-with-MLflow-and-DVC/research/Chest-CT-Scan-data.zip
# 100%|██████████| 43.0M/43.0M [01:29<00:00, 483kB/s]
# 'Chest-CT-Scan-data.zip'
